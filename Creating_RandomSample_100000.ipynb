# %%
import duckdb

con = duckdb.connect("developer_project.duckdb")

# %% [markdown]
# If you want the same sample every time (important for modeling/debugging)

# %%
# Activity sample
con.execute("""
CREATE OR REPLACE TABLE activity_sample AS
SELECT *
FROM activity_final
ORDER BY RANDOM()
LIMIT 100000
""")
# Out:
# ---------------------------------------------------------------------------
#
# CatalogException                          Traceback (most recent call last)
#
# Cell In[2], line 2
#
#       1 # Activity sample
#
# ----> 2 con.execute("""
#
#       3 CREATE OR REPLACE TABLE activity_sample AS
#
#       4 SELECT *
#
#       5 FROM activity_final
#
#       6 ORDER BY RANDOM()
#
#       7 LIMIT 100000
#
#       8 """)
#
#
#
# CatalogException: Catalog Error: Table with name activity_final does not exist!
#
# Did you mean "pg_description"?
#
#
#
# LINE 4: FROM activity_final
#
#              ^

# %%
# Contact sample
con.execute("""
CREATE OR REPLACE TABLE contact_sample AS
SELECT *
FROM contact_final
ORDER BY RANDOM()
LIMIT 100000
""")

# %%
# SDK downloads sample
con.execute("""
CREATE OR REPLACE TABLE sdk_download_sample AS
SELECT *
FROM sdk_download_final
ORDER BY RANDOM()
LIMIT 100000
""")

# %%
con.execute("""
COPY activity_sample TO 'Data/activity_sample.csv' (HEADER, DELIMITER ',')
""")

con.execute("""
COPY contact_sample TO 'Data/contact_sample.csv' (HEADER, DELIMITER ',')
""")

con.execute("""
COPY sdk_download_sample TO 'Data/sdk_download_sample.csv' (HEADER, DELIMITER ',')
""")
