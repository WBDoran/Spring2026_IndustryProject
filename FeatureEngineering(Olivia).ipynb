# %%
import duckdb
import pandas as pd
import numpy as np
from pathlib import Path

DB_PATH = "developer_project.duckdb"
con = duckdb.connect(DB_PATH)

# %%
con.execute("""
CREATE OR REPLACE TABLE activity_base_v2 AS
SELECT * FROM read_parquet('activity_base_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:13.14 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE activity_labeled_v2 AS
SELECT * FROM read_parquet('activity_labeled_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:47.52 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE activity_dictionary_v2 AS
SELECT * FROM read_parquet('activity_dictionary_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE activity_effort_mapping_ai_v2 AS
SELECT * FROM read_parquet('activity_effort_mapping_ai_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE contact_one_row_v2 AS
SELECT * FROM read_parquet('contact_one_row_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:04.30 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_activation_v2 AS
SELECT * FROM read_parquet('dev_activation_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_contact_persona_v2 AS
SELECT * FROM read_parquet('dev_contact_persona_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_dormancy_status_v2 AS
SELECT * FROM read_parquet('dev_dormancy_status_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_effort_level_v2 AS
SELECT * FROM read_parquet('dev_effort_level_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:02.62 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_features_lifetime_v2 AS
SELECT * FROM read_parquet('dev_features_lifetime_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:04.71 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_journey_state_v2 AS
SELECT * FROM read_parquet('dev_journey_state_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_meaningful_week_v2 AS
SELECT * FROM read_parquet('dev_meaningful_week_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_persona_v2 AS
SELECT * FROM read_parquet('dev_persona_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:02.24 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_recency_features_v2 AS
SELECT * FROM read_parquet('dev_recency_features_v2.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:02.33 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_profile_final_v4 AS
SELECT * FROM read_parquet('dev_profile_final_v4.parquet')
""")
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:12.60 elapsed)

# %%
con.execute("""
CREATE OR REPLACE TABLE dev_weekly_features_v2 AS
SELECT * FROM read_parquet('dev_weekly_features_v2.parquet')
""")

# %%
con.execute("""
CREATE OR REPLACE TABLE developer_universe_v2 AS
SELECT * FROM read_parquet('developer_universe_v2.parquet')
""")
