# %%
import duckdb

con = duckdb.connect("developer_project.duckdb")

# %%
display(con.execute("SHOW TABLES").fetchdf())
# Out:
#                  name
# 0      activity_clean
# 1        activity_raw
# 2       contact_clean
# 3         contact_raw
# 4  sdk_download_clean
# 5    sdk_download_raw

# %% [markdown]
# ### Analysis for `DEVPM_8674_Cal_Poly_Export_dev_activity.csv`

# %%
con.execute("SELECT COUNT(*) FROM activity_clean").fetchdf()
# Out:
#    count_star()
# 0      69347526

# %%
con.execute("""SELECT column_name
FROM information_schema.columns
WHERE table_name = 'activity_raw'""").fetchdf()
# Out:
#                column_name
# 0                 activity
# 1            activity_date
# 2            activity_name
# 3            activity_type
# 4            activity_role
# 5      activity_attendance
# 6              dev_contact
# 7           activity_score
# 8                 filepath
# 9              activity_id
# 10                     pk1
# 11                     pk2
# 12             lead_source
# 13      nvidia_campaign_id
# 14  gtc_nvidia_campaign_id
# 15     lead_source_details

# %%
con.execute("SUMMARIZE activity_clean").fetchdf()
# Out:
#            column_name column_type  \
# 0          dev_contact     VARCHAR
# 1             activity     VARCHAR
# 2        activity_name     VARCHAR
# 3        activity_type     VARCHAR
# 4        activity_role     VARCHAR
# 5  activity_attendance     VARCHAR
# 6       activity_score      DOUBLE
# 7        activity_date   TIMESTAMP
# 8          activity_id     VARCHAR
#
#                                                  min  \
# 0  0003027cbcc9f926a435232e311b3a5ffcbb0d16668d12...
# 1                                               Brev
# 2  (COURSE ENDING ON 7/1/24) High-Performance Com...
# 3                             API Catalog Hosted API
# 4                                      *Showstopper*
# 5                                                 15
# 6                                                0.0
# 7                                2020-01-01 00:00:00
# 8  --06jdo1meBBcl3t43Bw8twy5qo4b-WOFu9r_NPZ5JQ_20...
#
# ...

# %%
con.execute("""
SELECT activity_name, COUNT(*) AS count
FROM activity_raw
GROUP BY activity_name
ORDER BY count DESC
""").fetchdf()
# Out:
#                                             activity_name     count
# 0                                             JetPack SDK  10316702
# 1                                                   cuDNN   8242287
# 2                                                 jetpack   7365167
# 3                                               Developer   6527784
# 4                                                     NaN   4940143
# ...                                                   ...       ...
# 231251                  cuda-q-academic-launchable-d7495d         1
# 231252                      nvidia-tensorrt-llama3-7a649d         1
# 231253                          physicalai-6000ada-433292         1
# 231254                               aelangovan-8a100nvme         1
# 231255  GPU Unix Graphics: Linux: Unable to determine ...         1
#
# [231256 rows x 2 columns]

# %%
con.execute("""
SELECT activity_type, COUNT(*) AS count
FROM activity_clean
GROUP BY activity_type
ORDER BY count DESC
""").fetchdf()
# Out:
#              activity_type     count
# 0                Installer  36999321
# 1                 Approved   6654555
# 2   API Catalog Hosted API   6466203
# 3                Container   5345238
# 4            Documentation   1791479
# ..                     ...       ...
# 59                     NaN         3
# 60                    true         3
# 61                   image         3
# 62                Document         2
# 63                  NVINFO         2
#
# [64 rows x 2 columns]

# %%
con.execute("""
SELECT activity_score, COUNT(*) AS count
FROM activity_clean
GROUP BY activity_score
ORDER BY count DESC
""").fetchdf()
# Out:
#     activity_score     count
# 0              3.0  40386220
# 1              1.0  10136402
# 2              0.0   7304120
# 3              5.0   5173631
# 4             10.0   1907972
# 5             20.0   1435932
# 6              NaN    906358
# 7              6.0    635828
# 8              4.0    569597
# 9             40.0    498176
# 10             2.0    150807
# 11             8.0    143233
# 12            15.0     77497
# 13           100.0     21750
# 14        949156.0         1
# 15        948905.0         1
# 16        949763.0         1

# %%
con.execute("""
SELECT dev_contact, COUNT(*) AS count
FROM activity_clean
GROUP BY dev_contact
ORDER BY count DESC
""").fetchdf()
# Out:
#         dev_contact    count
# 0           5903679  2027375
# 1           5886356   789400
# 2           3931685   187095
# 3           1303597   151947
# 4           2028858   142980
# ...             ...      ...
# 7660274     4690931        1
# 7660275     3030662        1
# 7660276     3892437        1
# 7660277     8404906        1
# 7660278     8753915        1
#
# [7660279 rows x 2 columns]

# %%
# Check duplicates (replace with primary key if known)
display(con.execute("""
SELECT 
    COUNT(*) AS total_rows,
    COUNT(*) - (
        SELECT COUNT(*)
        FROM (SELECT DISTINCT * FROM activity_clean)
    ) AS duplicate_rows
FROM activity_clean
""").fetchdf())
# Out:
#    count_star()
# 0      69347526
# 100% ▕██████████████████████████████████████▏ (00:00:13.32 elapsed)
#    total_rows  duplicate_rows
# 0    69347526          163806

# %% [markdown]
# ### Analysis for `DEVPM_8674_Cal_Poly_Export_dev_contact.csv`

# %%
con.execute("SELECT COUNT(*) FROM contact_clean").fetchdf()
# Out:
#    count_star()
# 0       8903197

# %%
con.execute("SELECT DISTINCT developer_id FROM contact_clean").fetchdf()
# Out:
#         developer_id
# 0            8012571
# 1            8127117
# 2            8283771
# 3            8396451
# 4            8432920
# ...              ...
# 8903192      3012458
# 8903193      4944940
# 8903194      5532195
# 8903195      5185069
# 8903196      5561057
#
# [8903197 rows x 1 columns]

# %%
con.execute("""SELECT column_name
FROM information_schema.columns
WHERE table_name = 'contact_clean'""").fetchdf()
# Out:
#                         column_name
# 0                      developer_id
# 1        program_application_source
# 2                           country
# 3                            region
# 4                        sub_region
# 5                              zone
# 6                         territory
# 7         organization_english_name
# 8                 development_areas
# 9           other_development_areas
# 10        industry_segment_vertical
# 11  other_industry_segment_vertical
# 12    sub_industry_segment_vertical
# 13               fields_of_interest
# 14         other_fields_of_interest
# 15   first_program_application_date
# 16                       account_id
# 17                     account_name
# 18               last_activity_date
# 19               last_modified_date
# 20                     created_date
# 21                    wwfo_category
# 22                 wwfo_target_list
# 23         account_industry_segment
# 24                   account_source
# ...

# %%
con.execute("SUMMARIZE contact_clean").fetchdf()
# Out:
#                         column_name column_type  \
# 0                      developer_id     VARCHAR
# 1        program_application_source     VARCHAR
# 2                           country     VARCHAR
# 3                            region     VARCHAR
# 4                        sub_region     VARCHAR
# 5                              zone     VARCHAR
# 6                         territory     VARCHAR
# 7         organization_english_name     VARCHAR
# 8                 development_areas     VARCHAR
# 9           other_development_areas     VARCHAR
# 10        industry_segment_vertical     VARCHAR
# 11  other_industry_segment_vertical     VARCHAR
# 12    sub_industry_segment_vertical     VARCHAR
# 13               fields_of_interest     VARCHAR
# 14         other_fields_of_interest     VARCHAR
# 15   first_program_application_date   TIMESTAMP
# 16                       account_id     VARCHAR
# 17                     account_name     VARCHAR
# ...

# %%
# Check duplicates (replace with primary key if known)
display(con.execute("""
SELECT 
    COUNT(*) AS total_rows,
    COUNT(*) - (
        SELECT COUNT(*)
        FROM (SELECT DISTINCT * FROM contact_clean)
    ) AS duplicate_rows
FROM contact_clean
""").fetchdf())
# Out:
#    total_rows  duplicate_rows
# 0     8903197               0

# %% [markdown]
# ### Analysis for `DEVPM_8674_Cal_Poly_Export_sdk_download.csv`

# %%
con.execute("SELECT COUNT(*) FROM sdk_download_clean").fetchdf()
# Out:
#    count_star()
# 0      93038213

# %%
con.execute("""SELECT column_name
FROM information_schema.columns
WHERE table_name = 'sdk_download_raw'""").fetchdf()
# Out:
#         column_name
# 0            source
# 1          sdk_name
# 2       PRODUCTNAME
# 3    PRODUCTRELEASE
# 4           country
# 5            region
# 6         subregion
# 7         territory
# 8              zone
# 9      downloaddate
# 10         FILETYPE
# 11  OPERATINGSYSTEM
# 12  OS_DISTRIBUTION
# 13     ARCHITECTURE
# 14              KPI
# 15    downloadcount

# %%
con.execute("SUMMARIZE sdk_download_clean").fetchdf()
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:02.49 elapsed)
#          column_name column_type                                 min  \
# 0             source     VARCHAR                                 CDN
# 1           sdk_name     VARCHAR                              3DGRUT
# 2       product_name     VARCHAR  (Linux) Acoustic Echo Cancellation
# 3    product_release     VARCHAR                                 0.0
# 4            country     VARCHAR                                  AD
# 5             region     VARCHAR                                APAC
# 6          subregion     VARCHAR                              Africa
# 7          territory     VARCHAR                              AFRICA
# 8               zone     VARCHAR                                 ANZ
# 9      download_date        DATE                          2020-01-01
# 10         file_type     VARCHAR                                   ?
# 11  operating_system     VARCHAR                                 AIX
# ...

# %%
# Check duplicates (replace with primary key if known)
display(con.execute("""
SELECT 
    COUNT(*) AS total_rows,
    COUNT(*) - (
        SELECT COUNT(*)
        FROM (SELECT DISTINCT * FROM sdk_download_clean)
    ) AS duplicate_rows
FROM sdk_download_clean
""").fetchdf())
# Out:
# 100% ▕██████████████████████████████████████▏ (00:00:14.11 elapsed)
#    total_rows  duplicate_rows
# 0    93038213          275400
